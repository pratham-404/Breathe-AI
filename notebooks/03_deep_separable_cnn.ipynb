# %% [markdown]
# # Deep Separable CNN — complete training notebook
#
# This notebook contains the complete data preparation, model construction, training, evaluation and export workflow. No training module outside this notebook is used. Run cells in order only after reviewing them.
#
# **Goal:** combine efficient separable convolutions with residual shortcuts so a deeper network can learn without unstable gradients. The final cell registers the artifact so the backend and model selector can use it.

# %% [markdown]
# ## End-to-end flow
#
# ```text
# image files → parallel decode/resize → augmentation → model → pneumonia probability
#             → untouched test metrics → .keras artifact → web application
# ```
#
# The test set is isolated until final evaluation. This prevents test information leaking into model selection.

# %% [markdown]
# ## 1. Paths and experiment controls
#
# The seed fixes the data split and initial weights. Image size, batch size, epochs and learning rate are explicit so runtime and model quality can be tuned from one cell.

# %%
from pathlib import Path
from datetime import datetime, timezone
import hashlib
import json
import os
import random

import numpy as np
import tensorflow as tf

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
DATASET = ROOT / "dataset" / "archive" / "chest_xray"
CATALOG = ROOT / "server" / "model_catalog.json"
ARTIFACT = ROOT / "server" / "artifacts" / "deep-separable-cnn.keras"
MODEL_ID = "deep-separable-cnn"
IMAGE_SIZE = 180
BATCH_SIZE = 24
EPOCHS = 40
LEARNING_RATE = 0.0003
SEED = 42

assert DATASET.is_dir(), f"Dataset not found: {DATASET}"
ARTIFACT.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. CPU/GPU execution and multithreading
#
# TensorFlow parallelizes numerical kernels. The explicit thread pools use available CPU cores, while `AUTOTUNE` below overlaps file decoding and preprocessing with model execution. Training multiple models simultaneously would normally cause RAM/GPU contention, so each notebook trains one model efficiently.

# %%
# Configure TensorFlow before it creates its execution context.
CPU_THREADS = max(1, (os.cpu_count() or 2) - 1)
try:
    tf.config.threading.set_intra_op_parallelism_threads(CPU_THREADS)
    tf.config.threading.set_inter_op_parallelism_threads(max(1, CPU_THREADS // 2))
except RuntimeError:
    print("Thread pools already initialized; restart the kernel to change them.")

random.seed(SEED)
np.random.seed(SEED)
tf.keras.utils.set_random_seed(SEED)
print({"cpu_threads": CPU_THREADS, "gpus": tf.config.list_physical_devices("GPU")})
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# {'cpu_threads': 19, 'gpus': []}

# %% [markdown]
# ## 3. Discover and split the data
#
# The training and small validation folders are combined, then split 80/20 within each class. Stratification preserves the Normal/Pneumonia ratio. Seed 42 makes the assignment repeatable. The original test folder remains untouched.

# %%
EXTENSIONS = {".jpg", ".jpeg", ".png"}

def image_files(split, class_name, label):
    folder = DATASET / split / class_name
    if not folder.is_dir():
        raise FileNotFoundError(f"Missing dataset folder: {folder}")
    return [(str(path), label) for path in sorted(folder.iterdir()) if path.suffix.lower() in EXTENSIONS]

pool = image_files("train", "NORMAL", 0) + image_files("train", "PNEUMONIA", 1)
pool += image_files("val", "NORMAL", 0) + image_files("val", "PNEUMONIA", 1)
test_samples = image_files("test", "NORMAL", 0) + image_files("test", "PNEUMONIA", 1)

rng = random.Random(SEED)
train_samples, validation_samples = [], []
for label in (0, 1):
    group = [sample for sample in pool if sample[1] == label]
    rng.shuffle(group)
    cut = round(len(group) * 0.2)
    validation_samples.extend(group[:cut])
    train_samples.extend(group[cut:])
rng.shuffle(train_samples)
rng.shuffle(validation_samples)

def counts(samples):
    return {"normal": sum(label == 0 for _, label in samples), "pneumonia": sum(label == 1 for _, label in samples)}

{"train": counts(train_samples), "validation": counts(validation_samples), "test": counts(test_samples)}
# Out:
# {'train': {'normal': 1079, 'pneumonia': 3106},
#  'validation': {'normal': 270, 'pneumonia': 777},
#  'test': {'normal': 234, 'pneumonia': 390}}

# %% [markdown]
# ## 4. Build the parallel input pipeline
#
# Decoding and resizing run on multiple CPU threads. Prefetch prepares the next batch while the model processes the current one. Balanced class weights stop majority-class accuracy from hiding poor Normal recognition.

# %%
def load_image(path, label):
    image = tf.io.decode_image(tf.io.read_file(path), channels=3, expand_animations=False)
    image.set_shape((None, None, 3))
    image = tf.image.resize(tf.cast(image, tf.float32), (IMAGE_SIZE, IMAGE_SIZE)) / 255.0
    return image, tf.cast(label, tf.float32)

def make_dataset(samples, training=False):
    paths, labels = zip(*samples)
    data = tf.data.Dataset.from_tensor_slices((list(paths), list(labels)))
    if training:
        data = data.shuffle(len(samples), seed=SEED, reshuffle_each_iteration=True)
    return (data
            .map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
            .batch(BATCH_SIZE)
            .prefetch(tf.data.AUTOTUNE))

train_data = make_dataset(train_samples, training=True)
validation_data = make_dataset(validation_samples)
test_data = make_dataset(test_samples)

class_counts = np.bincount([label for _, label in train_samples], minlength=2)
class_weight = {index: len(train_samples) / (2 * count) for index, count in enumerate(class_counts)}
class_weight
# Out:
# {0: np.float64(1.9392956441149212), 1: np.float64(0.6736960721184804)}

# %% [markdown]
# ## 5. Define the model from random initialization
#
# Residual shortcuts give gradients a direct path through the network, making additional stages trainable. Separable convolutions keep that depth affordable. The dense layer combines the final features, while dropout limits co-adaptation and overfitting.
#
# ```text
# 180² RGB → Conv32 → residual Sep64 → Sep128 → Sep256 → Sep384 → GlobalAvgPool → Dense128 → sigmoid
# ```

# %%
augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.04),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
], name="augmentation")

def residual_stage(x, filters):
    shortcut = tf.keras.layers.Conv2D(filters, 1, strides=2, padding="same")(x)
    x = tf.keras.layers.SeparableConv2D(filters, 3, strides=2, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.SeparableConv2D(filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    return tf.keras.layers.Activation("relu")(tf.keras.layers.Add()([x, shortcut]))

inputs = tf.keras.layers.Input((IMAGE_SIZE, IMAGE_SIZE, 3))
x = augmentation(inputs)
x = tf.keras.layers.Conv2D(32, 3, padding="same", activation="relu")(x)
for filters in (64, 128, 256, 384):
    x = residual_stage(x, filters)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation="relu")(x)
x = tf.keras.layers.Dropout(0.4)(x)
model = tf.keras.Model(inputs, tf.keras.layers.Dense(1, activation="sigmoid")(x), name=MODEL_ID)

# %% [markdown]
# ## 6. Compile
#
# Binary cross-entropy trains a calibrated two-class probability. Adam adapts parameter updates. Accuracy is intuitive; AUC measures ranking quality across thresholds.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryAccuracy(name="accuracy"), tf.keras.metrics.AUC(name="auc")],
)
model.summary()
print({"parameters": model.count_params(), "artifact": str(ARTIFACT)})
# Out:
# Model: "deep-separable-cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 180, 180,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augmentation        │ (None, 180, 180,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 180, 180,  │        896 │ augmentation[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 90, 90,    │      2,400 │ conv2d[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 90, 90,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 90, 90,    │      4,736 │ batch_normalizat… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 90, 90,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 90, 90,    │      2,112 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 90, 90,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 90, 90,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 45, 45,    │      8,896 │ activation[0][0]  │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 45, 45,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 45, 45,    │     17,664 │ batch_normalizat… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 45, 45,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 45, 45,    │      8,320 │ activation[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 45, 45,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 45, 45,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 23, 23,    │     34,176 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 23, 23,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 23, 23,    │     68,096 │ batch_normalizat… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 23, 23,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 23, 23,    │     33,024 │ activation_1[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 23, 23,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 23, 23,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 12, 12,    │    100,992 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 12, 12,    │    151,296 │ batch_normalizat… │
# │ (SeparableConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 12, 12,    │     98,688 │ activation_2[0][… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 12, 12,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ activation_3[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     49,280 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 587,361 (2.24 MB)
#  Trainable params: 584,033 (2.23 MB)
#  Non-trainable params: 3,328 (13.00 KB)
# {'parameters': 587361, 'artifact': 'C:\\Users\\praloya\\Desktop\\New folder\\projects\\Breathe-AI\\server\\artifacts\\deep-separable-cnn.keras'}

# %% [markdown]
# ## 7. Train — long-running cell
#
# Checkpointing retains the best validation-loss model. Early stopping avoids wasted epochs after progress stalls. Learning-rate reduction makes smaller, more precise updates near a good solution. Augmentation is enabled only for training.

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(ARTIFACT, monitor="val_loss", save_best_only=True),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.3, min_lr=1e-7),
]

history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=EPOCHS,
    class_weight=class_weight,
    callbacks=callbacks,
)
print({
    "epochs_completed": len(history.history["loss"]),
    "best_validation_loss": min(history.history["val_loss"]),
    "best_validation_accuracy": max(history.history["val_accuracy"]),
})
# Out:
# Epoch 1/40
# c:\Users\praloya\Desktop\New folder\projects\Breathe-AI\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 82s 431ms/step - accuracy: 0.8643 - auc: 0.9425 - loss: 0.3026 - val_accuracy: 0.7421 - val_auc: 0.4402 - val_loss: 0.6464 - learning_rate: 3.0000e-04
# Epoch 2/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 74s 421ms/step - accuracy: 0.9238 - auc: 0.9771 - loss: 0.1894 - val_accuracy: 0.7421 - val_auc: 0.5268 - val_loss: 0.6348 - learning_rate: 3.0000e-04
# Epoch 3/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.9336 - auc: 0.9821 - loss: 0.1672 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.4391 - learning_rate: 3.0000e-04
# Epoch 4/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 423ms/step - accuracy: 0.9410 - auc: 0.9843 - loss: 0.1569 - val_accuracy: 0.7421 - val_auc: 0.7334 - val_loss: 1.3926 - learning_rate: 3.0000e-04
# Epoch 5/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 428ms/step - accuracy: 0.9438 - auc: 0.9871 - loss: 0.1416 - val_accuracy: 0.9456 - val_auc: 0.9920 - val_loss: 0.1209 - learning_rate: 3.0000e-04
# Epoch 6/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 425ms/step - accuracy: 0.9508 - auc: 0.9877 - loss: 0.1357 - val_accuracy: 0.9608 - val_auc: 0.9910 - val_loss: 0.1080 - learning_rate: 3.0000e-04
# Epoch 7/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 75s 425ms/step - accuracy: 0.9510 - auc: 0.9881 - loss: 0.1339 - val_accuracy: 0.9150 - val_auc: 0.9922 - val_loss: 0.2091 - learning_rate: 3.0000e-04
# Epoch 8/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 80s 454ms/step - accuracy: 0.9524 - auc: 0.9900 - loss: 0.1244 - val_accuracy: 0.4776 - val_auc: 0.9020 - val_loss: 2.1003 - learning_rate: 3.0000e-04
# Epoch 9/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 81s 457ms/step - accuracy: 0.9515 - auc: 0.9894 - loss: 0.1269 - val_accuracy: 0.9102 - val_auc: 0.9913 - val_loss: 0.2164 - learning_rate: 3.0000e-04
# Epoch 10/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 476ms/step - accuracy: 0.9627 - auc: 0.9934 - loss: 0.1032 - val_accuracy: 0.9713 - val_auc: 0.9944 - val_loss: 0.0763 - learning_rate: 9.0000e-05
# Epoch 11/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 85s 485ms/step - accuracy: 0.9658 - auc: 0.9938 - loss: 0.0973 - val_accuracy: 0.9608 - val_auc: 0.9938 - val_loss: 0.1039 - learning_rate: 9.0000e-05
# Epoch 12/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 89s 507ms/step - accuracy: 0.9613 - auc: 0.9941 - loss: 0.0969 - val_accuracy: 0.9656 - val_auc: 0.9938 - val_loss: 0.0788 - learning_rate: 9.0000e-05
# Epoch 13/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 76s 428ms/step - accuracy: 0.9687 - auc: 0.9947 - loss: 0.0892 - val_accuracy: 0.9656 - val_auc: 0.9944 - val_loss: 0.0856 - learning_rate: 9.0000e-05
# Epoch 14/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 436ms/step - accuracy: 0.9644 - auc: 0.9947 - loss: 0.0892 - val_accuracy: 0.9647 - val_auc: 0.9947 - val_loss: 0.0896 - learning_rate: 2.7000e-05
# Epoch 15/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 78s 445ms/step - accuracy: 0.9699 - auc: 0.9958 - loss: 0.0790 - val_accuracy: 0.9685 - val_auc: 0.9949 - val_loss: 0.0794 - learning_rate: 2.7000e-05
# Epoch 16/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 83s 469ms/step - accuracy: 0.9737 - auc: 0.9960 - loss: 0.0786 - val_accuracy: 0.9694 - val_auc: 0.9949 - val_loss: 0.0798 - learning_rate: 2.7000e-05
# Epoch 17/40
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 84s 475ms/step - accuracy: 0.9754 - auc: 0.9956 - loss: 0.0763 - val_accuracy: 0.9666 - val_auc: 0.9949 - val_loss: 0.0871 - learning_rate: 8.1000e-06
# {'epochs_completed': 17, 'best_validation_loss': 0.07630910724401474, 'best_validation_accuracy': 0.9713466763496399}

# %% [markdown]
# ## 8. Evaluate on untouched images
#
# The comparison includes accuracy, loss, precision, recall/sensitivity, specificity, F1, AUC and a confusion matrix. Threshold 0.5 is stored with the metrics so every model is judged consistently.

# %%
model = tf.keras.models.load_model(ARTIFACT, compile=False)
probabilities = np.asarray(model.predict(test_data, verbose=1)).reshape(-1)
actual = np.concatenate([labels.numpy() for _, labels in test_data]).astype(int)
predicted = (probabilities >= 0.5).astype(int)

tn = int(np.sum((actual == 0) & (predicted == 0)))
fp = int(np.sum((actual == 0) & (predicted == 1)))
fn = int(np.sum((actual == 1) & (predicted == 0)))
tp = int(np.sum((actual == 1) & (predicted == 1)))
divide = lambda numerator, denominator: float(numerator / denominator) if denominator else 0.0
precision = divide(tp, tp + fp)
recall = divide(tp, tp + fn)
clipped = np.clip(probabilities, 1e-7, 1 - 1e-7)

metrics = {
    "status": "verified_local_test_split",
    "accuracy": divide(tp + tn, len(actual)),
    "loss": float(-np.mean(actual * np.log(clipped) + (1 - actual) * np.log(1 - clipped))),
    "precision": precision,
    "recall": recall,
    "f1": divide(2 * precision * recall, precision + recall),
    "specificity": divide(tn, tn + fp),
    "auc": float(tf.keras.metrics.AUC()(actual, probabilities).numpy()),
    "confusion_matrix": {"tn": tn, "fp": fp, "fn": fn, "tp": tp},
    "samples": len(actual),
    "threshold": 0.5,
}
metrics
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step
# {'status': 'verified_local_test_split',
#  'accuracy': 0.7916666666666666,
#  'loss': 0.5714055575425692,
#  'precision': 0.7529182879377432,
#  'recall': 0.9923076923076923,
#  'f1': 0.8561946902654868,
#  'specificity': 0.45726495726495725,
#  'auc': 0.9400065541267395,
#  'confusion_matrix': {'tn': 107, 'fp': 127, 'fn': 3, 'tp': 387},
#  'samples': 624,
#  'threshold': 0.5}

# %% [markdown]
# ## 9. Save and register for inference
#
# This cell hashes the best artifact and writes its verified metrics and parameter count to the catalog. The backend verifies the hash before loading it.

# %%
def sha256(path):
    digest = hashlib.sha256()
    with path.open("rb") as stream:
        for chunk in iter(lambda: stream.read(1024 * 1024), b""):
            digest.update(chunk)
    return digest.hexdigest()

digest = sha256(ARTIFACT)
catalog = json.loads(CATALOG.read_text(encoding="utf-8"))
entry = next(item for item in catalog["models"] if item["id"] == MODEL_ID)
entry["parameters"] = int(model.count_params())
entry["metrics"] = metrics
entry["artifact"].update({
    "version": digest[:12],
    "sha256": digest,
    "status": "trained_and_checksum_verified",
    "trained_at": datetime.now(timezone.utc).isoformat(),
})
CATALOG.write_text(json.dumps(catalog, indent=2) + "\n", encoding="utf-8")
print({"saved": str(ARTIFACT), "model_version": digest[:12], "catalog_updated": str(CATALOG)})
# Out:
# {'saved': 'C:\\Users\\praloya\\Desktop\\New folder\\projects\\Breathe-AI\\server\\artifacts\\deep-separable-cnn.keras', 'model_version': '895be9e2f347', 'catalog_updated': 'C:\\Users\\praloya\\Desktop\\New folder\\projects\\Breathe-AI\\server\\model_catalog.json'}

# %% [markdown]
# ## What to do after running
#
# Restart the backend, refresh the web application, choose **Deep Separable CNN**, and upload an image. Retraining this notebook replaces only this model's artifact and catalog metrics.
